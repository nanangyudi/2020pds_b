# %% [markdown]
# <a href="https://colab.research.google.com/github/nanangyudi/2020pds_b/blob/main/TUGAS_AKHIR_PDS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Tujuan Bisnis :
# untuk menganalisis film apa saja yang ada di netflix beserta dengan detil dari film tersebut.
#
# Analisa pendekatan :
# analisa dilakukan dengan melakukan filter pada daftar film yang ada
#
# Pengumpulan Data :
# data dikumpulkan dari situs web kaggle.com
#
# Pemahaman terhadap data yang dikumpulkan :
# data berisi berbagai film yang mendetil mulai dari film id, tipe film, judul film, sutradara, pemeran, negara pembuat, tanggal pembuatan, tahun rilis, rating, lama waktu film, terdaftar dimana saja, hingga deskripsi

# %% [markdown]
# **EKSPLORASI DATA**

# %%
df["type"].value_counts()
# Out:
# Movie      4265
# TV Show    1969
# Name: type, dtype: int64

# %%
import numpy as np 
import pandas as pd 
import os
for dirname, _, filenames in os.walk ('netflix_titles.csv'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
df = pd.read_csv("netflix_titles.csv")
df.head(10)
# Out:
#     show_id  ...                                        description
# 0  81145628  ...  Before planning an awesome wedding for his gra...
# 1  80117401  ...  Jandino Asporaat riffs on the challenges of ra...
# 2  70234439  ...  With the help of three human allies, the Autob...
# 3  80058654  ...  When a prison ship crash unleashes hundreds of...
# 4  80125979  ...  When nerdy high schooler Dani finally attracts...
# 5  80163890  ...  A young journalist is forced into a life of cr...
# 6  70304989  ...  In a dystopian future, an insurance adjuster f...
# 7  80164077  ...  Fabrizio Copano takes audience participation t...
# 8  80117902  ...  As California's 2016 fire season rages, brave ...
# 9  70304990  ...  A struggling couple can't believe their luck w...
#
# [10 rows x 12 columns]

# %%
df.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
df["date_added"] = df['date_added'].str.slice(start=-4)
df["date_added"]
# Out:
# 0       2019
# 1       2016
# 2       2018
# 3       2018
# 4       2017
#         ...
# 6229     NaN
# 6230     NaN
# 6231     NaN
# 6232     NaN
# 6233     NaN
# Name: date_added, Length: 6234, dtype: object

# %%
df.dropna(inplace = True)
df
# Out:
#        show_id  ...                                        description
# 0     81145628  ...  Before planning an awesome wedding for his gra...
# 4     80125979  ...  When nerdy high schooler Dani finally attracts...
# 6     70304989  ...  In a dystopian future, an insurance adjuster f...
# 7     80164077  ...  Fabrizio Copano takes audience participation t...
# 9     70304990  ...  A struggling couple can't believe their luck w...
# ...        ...  ...                                                ...
# 6142  80063224  ...  A talented batch of amateur bakers face off in...
# 6158  80164216  ...  When Paris is in peril, Marinette becomes Lady...
# 6167  80115328  ...  A link in their pasts leads an honest cop to a...
# 6182  80176842  ...  Male celebs play make-believe as high schooler...
# 6213  80126599  ...  Destiny brings Mecnun and Leyla together as ne...
#
# [3774 rows x 12 columns]

# %%
print(df['date_added'].dtypes)
# Out:
# object

# %%
df["date_added"].values.min()
# Out:
# '2008'

# %%
df["date_added"].values.max()
# Out:
# '2020'

# %%
df["date_added"] = df["date_added"].astype("int64")
df["date_added"]
# Out:
# 0       2019
# 4       2017
# 6       2017
# 7       2017
# 9       2017
#         ...
# 6142    2019
# 6158    2019
# 6167    2019
# 6182    2019
# 6213    2017
# Name: date_added, Length: 3774, dtype: int64

# %%
year_cuts = pd.cut(df["date_added"],[2008,2015,2020])
year_cuts
# Out:
# 0       (2015, 2020]
# 4       (2015, 2020]
# 6       (2015, 2020]
# 7       (2015, 2020]
# 9       (2015, 2020]
#             ...
# 6142    (2015, 2020]
# 6158    (2015, 2020]
# 6167    (2015, 2020]
# 6182    (2015, 2020]
# 6213    (2015, 2020]
# Name: date_added, Length: 3774, dtype: category
# Categories (2, interval[int64]): [(2008, 2015] < (2015, 2020]]

# %%
df["type"].isnull()
# Out:
# 0       False
# 4       False
# 6       False
# 7       False
# 9       False
#         ...
# 6142    False
# 6158    False
# 6167    False
# 6182    False
# 6213    False
# Name: type, Length: 3774, dtype: bool

# %%
from sklearn import preprocessing
le_type = preprocessing.LabelEncoder()
le_type.fit(['Movie','TV Show'])
df.iloc[:,1] = le_type.transform(df.iloc[:,1]) 
df.iloc[0:10]
# Out:
#      show_id  ...                                        description
# 0   81145628  ...  Before planning an awesome wedding for his gra...
# 4   80125979  ...  When nerdy high schooler Dani finally attracts...
# 6   70304989  ...  In a dystopian future, an insurance adjuster f...
# 7   80164077  ...  Fabrizio Copano takes audience participation t...
# 9   70304990  ...  A struggling couple can't believe their luck w...
# 11  70299204  ...  When beer magnate Alfred "Freddy" Heineken is ...
# 19  80057969  ...  A man in an unsatisfying marriage recalls the ...
# 20  80060297  ...  A filmmaker working on a documentary about lov...
# 21  80046728  ...  A brain-addled war vet, a failing band manager...
# 23  70304988  ...  In 1899, a young doctor arrives at an asylum f...
#
# [10 rows x 12 columns]

# %% [markdown]
# **PEMODELAN DATA**

# %%
df.pivot_table("type",["date_added",year_cuts],"release_year",aggfunc="sum")
# Out:
# release_year             1942  1944  1945  1946  ...  2017  2018  2019  2020
# date_added date_added                            ...
# 2009       (2008, 2015]   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN
# 2010       (2008, 2015]   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN
# 2011       (2008, 2015]   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN
# 2012       (2008, 2015]   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN
# 2013       (2008, 2015]   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN
# 2014       (2008, 2015]   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN
# 2015       (2008, 2015]   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN
# 2016       (2015, 2020]   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN
# 2017       (2015, 2020]   0.0   0.0   0.0   0.0  ...  11.0   0.0   NaN   NaN
# 2018       (2015, 2020]   NaN   NaN   NaN   0.0  ...   3.0  12.0   0.0   NaN
# ...

# %% [markdown]
# **EVALUASI DATA**

# %%
import seaborn as sns
from matplotlib import pyplot

fig, ax = pyplot.subplots(figsize=(18,10))
df_heatmap = df.pivot_table("type",["date_added",year_cuts],"release_year",aggfunc="sum")
sns.heatmap(df_heatmap,annot = True,ax = ax);
